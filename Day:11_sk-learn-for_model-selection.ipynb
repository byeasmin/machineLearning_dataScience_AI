# %% [markdown]
# <a href="https://www.kaggle.com/code/yeasminbenin/day-11-sk-learn-for-model-selection?scriptVersionId=345116616" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ![image.png](attachment:bbe6c648-0f31-4066-b3d0-bc7c518063ee.png)

# %% [markdown]
# ![image.png](attachment:216dc1be-8ac0-4da9-bc3a-1961e3460fa5.png)
