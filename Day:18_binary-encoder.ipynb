# %% [markdown]
# # Limitation of one-hot encoding
#
# - **high dimension**

# %% [markdown]
# ![image.png](attachment:52a748e3-4cc7-4816-bf90-4427cde37113.png)

# %% [markdown]
# ![image.png](attachment:a68fabb6-b6d9-47a7-93c8-524fa3b1ff4b.png)

# %% [markdown]
# ![image.png](attachment:7a94884b-f2ee-4e5d-8d90-6078b6af4fd7.png)

# %% [markdown]
# # Implement with Python

# %%
import pandas as pd

# %%
import category_encoders as ce

# %%
data = {'Category': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C']}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category
# 0        A
# 1        B
# 2        C
# 3        A
# 4        B
# 5        C
# 6        A
# 7        B
# 8        C

# %%
df.shape
# Out:
# (9, 1)

# %%
import category_encoders as ce
encoder = ce.BinaryEncoder(cols=['Category'], return_df=True)

# %%
df_binary_encoded = encoder.fit_transform(df)

# %%
df_binary_encoded
# Out:
#    Category_0  Category_1
# 0           0           1
# 1           1           0
# 2           1           1
# 3           0           1
# 4           1           0
# 5           1           1
# 6           0           1
# 7           1           0
# 8           1           1
