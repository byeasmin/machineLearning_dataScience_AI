# %% [markdown]
# # Pandas DataFrame
#
# A **Pandas DataFrame** is a **two-dimensional, tabular data structure** in Python, similar to a **spreadsheet or SQL table**.
#
# It contains **rows and columns**, where each column can represent a different **feature or variable**.

# %% [markdown]
# # import lobrary

# %%
import pandas as pd

# %% [markdown]
# # Empty Dataframe

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %% [markdown]
# #### To work with a Pandas DataFrame, we need data. We can get the data from a list, dictionary, CSV or Excel file, or from anywhere else.

# %% [markdown]
# # List to DataFrame

# %%
city = ['Chittagong', 'Dhaka', 'Barishal']

# %%
df = pd.DataFrame(city)

# %%
df
# Out:
#             0
# 0  Chittagong
# 1       Dhaka
# 2    Barishal

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(city)
# Out:
# list

# %%
row, col = df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
  df.shape
# Out:
# (3, 1)

# %%
df = pd.DataFrame(city, columns = ['city_of_bd'], index = ['c1', 'c2', 'c3'])

# %%
df
# Out:
#     city_of_bd
# c1  Chittagong
# c2       Dhaka
# c3    Barishal

# %% [markdown]
# # Work with two lists

# %%
city2 = ['Cumilla', 'Barishal', 'Khulna']

# %%
df2 = pd.DataFrame(zip(city, city2), columns = ['city1', 'city2'])

# %%
df2
# Out:
#         city1     city2
# 0  Chittagong   Cumilla
# 1       Dhaka  Barishal
# 2    Barishal    Khulna

# %%
df.shape
# Out:
# (3, 1)

# %%
df2.shape
# Out:
# (3, 2)

# %%
city3 = [['Dhaka', 'Chittagong', 'Khulna', 'Sylhet'], ['Barishal', 'Rajshahi', 'Mymensingh', 'Rangpur']]

# %%
df4 = pd.DataFrame(city3, columns = ['city1', 'city2', 'city3', 'city4'])

# %%
df4
# Out:
#       city1       city2       city3    city4
# 0     Dhaka  Chittagong      Khulna   Sylhet
# 1  Barishal    Rajshahi  Mymensingh  Rangpur

# %% [markdown]
# # Dictionary to DataFrame

# %%
city
# Out:
# ['Chittagong', 'Dhaka', 'Barishal']

# %% [markdown]
# ##

# %%
city2
# Out:
# ['Cumilla', 'Barishal', 'Khulna']

# %%
 dict1 = {
     'city1': city,
     'city2': city2
 }

# %%
dict1
# Out:
# {'city1': ['Chittagong', 'Dhaka', 'Barishal'],
#  'city2': ['Cumilla', 'Barishal', 'Khulna']}

# %%
df5 = pd.DataFrame(dict1)

# %%
df5
# Out:
#         city1     city2
# 0  Chittagong   Cumilla
# 1       Dhaka  Barishal
# 2    Barishal    Khulna

# %%
type(dict1)
# Out:
# dict
