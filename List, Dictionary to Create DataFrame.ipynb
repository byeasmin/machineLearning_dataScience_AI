# %% [markdown]
# # Pandas DataFrame

# %% [markdown]
# ## Import Library

# %% [markdown]
# ## Convert 1D list to DataFrame

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: []
# Index: []>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city = ['Chittagong', 'Dhaka', 'Khulna']

# %%
city
# Out:
# ['Chittagong', 'Dhaka', 'Khulna']

# %%
df = pd.DataFrame(city)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#             0
# 0  Chittagong
# 1       Dhaka
# 2      Khulna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
df.info
# Out:
# <bound method DataFrame.info of             0
# 0  Chittagong
# 1       Dhaka
# 2      Khulna>

# %%
type(city)
# Out:
# list

# %%
row, col = df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
df.shape
# Out:
# (3, 1)

# %%
df
# Out:
#             0
# 0  Chittagong
# 1       Dhaka
# 2      Khulna

# %% [markdown]
# ## Set Row & Column name

# %%
df = pd.DataFrame(city, column = ['Bangladesh'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df = pd.DataFrame(city, column = ['Bangladesh'])
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'column'

# %%
df = pd.DataFrame(city, columns = ['Bangladesh'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Bangladesh  3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
df.info
# Out:
# <bound method DataFrame.info of    Bangladesh
# 0  Chittagong
# 1       Dhaka
# 2      Khulna>

# %%
df
# Out:
#    Bangladesh
# 0  Chittagong
# 1       Dhaka
# 2      Khulna

# %%
df = pd.DataFrame(city, columns = ['Bangladesh'], index = ['C1', 'C2', 'C3'])

# %%
df
# Out:
#     Bangladesh
# C1  Chittagong
# C2       Dhaka
# C3      Khulna

# %%
city2 = ['Rajshahi', 'Comilla', 'Barishal']

# %%
df = pd.DataFrame(zip(city, city2), columns = ['City1', 'City2'])

# %%
df
# Out:
#         City1     City2
# 0  Chittagong  Rajshahi
# 1       Dhaka   Comilla
# 2      Khulna  Barishal

# %%
df = pd.DataFrame(zip(city, city2), columns = ['City1', 'City2'], index = ['C1', 'C2', 'C3'])

# %%
df
# Out:
#          City1     City2
# C1  Chittagong  Rajshahi
# C2       Dhaka   Comilla
# C3      Khulna  Barishal

# %%
df.shape
# Out:
# (3, 2)

# %% [markdown]
# ## Convert 2D list to DataFrame

# %%
city3 = [['Bangladesh', 'Dhaka', 'Chittagong'], ['Russia', 'Moscow', 'Novosibirsk'], ['UK', 'London', 'Birmingham']]

# %%
city3
# Out:
# [['Bangladesh', 'Dhaka', 'Chittagong'],
#  ['Russia', 'Moscow', 'Novosibirsk'],
#  ['UK', 'London', 'Birmingham']]

# %%
df2 = pd.DataFrame(city3)

# %%
df2
# Out:
#             0       1            2
# 0  Bangladesh   Dhaka   Chittagong
# 1      Russia  Moscow  Novosibirsk
# 2          UK  London   Birmingham

# %%
df2 = pd.DataFrame(city3, columns = ['STATE', 'CITY_1', 'CITY_2'])

# %%
df2
# Out:
#         STATE  CITY_1       CITY_2
# 0  Bangladesh   Dhaka   Chittagong
# 1      Russia  Moscow  Novosibirsk
# 2          UK  London   Birmingham

# %%
df2 = pd.DataFrame(city3, columns = ['STATE', 'CITY_1', 'CITY_2'], index = ['1', '2', '3'])

# %%
df2
# Out:
#         STATE  CITY_1       CITY_2
# 1  Bangladesh   Dhaka   Chittagong
# 2      Russia  Moscow  Novosibirsk
# 3          UK  London   Birmingham

# %%
city
# Out:
# ['Chittagong', 'Dhaka', 'Khulna']

# %%
city2
# Out:
# ['Rajshahi', 'Comilla', 'Barishal']

# %% [markdown]
# # Dictionary to DataFrame

# %%
dict1 = {
    'City_1': city,
    'City_2': city2
}

# %%
dict1
# Out:
# {'City_1': ['Chittagong', 'Dhaka', 'Khulna'],
#  'City_2': ['Rajshahi', 'Comilla', 'Barishal']}

# %%
df3 = pd.DataFrame(dict1)

# %%
df3
# Out:
#        City_1    City_2
# 0  Chittagong  Rajshahi
# 1       Dhaka   Comilla
# 2      Khulna  Barishal

# %%
df3 = pd.DataFrame(dict1, index = ['1', '2', '3'])

# %%
df3
# Out:
#        City_1    City_2
# 1  Chittagong  Rajshahi
# 2       Dhaka   Comilla
# 3      Khulna  Barishal

# %%
type(dict1)
# Out:
# dict

# %%
city7 = [['Bangladesh', 'Comilla', 'Barishal'], ['Russia', 'Petersburg', 'Samara'], ['UK', 'Mancheste', 'Plymouth']]

# %%
city3
# Out:
# [['Bangladesh', 'Dhaka', 'Chittagong'],
#  ['Russia', 'Moscow', 'Novosibirsk'],
#  ['UK', 'London', 'Birmingham']]

# %%
dict2 = {
    'City_7': city3,
    'City_8': city7
}

# %%
dict2
# Out:
# {'City_7': [['Bangladesh', 'Dhaka', 'Chittagong'],
#   ['Russia', 'Moscow', 'Novosibirsk'],
#   ['UK', 'London', 'Birmingham']],
#  'City_8': [['Bangladesh', 'Comilla', 'Barishal'],
#   ['Russia', 'Petersburg', 'Samara'],
#   ['UK', 'Mancheste', 'Plymouth']]}

# %%
df8 = pd.DataFrame(dict2)

# %%
df8
# Out:
#                             City_7                           City_8
# 0  [Bangladesh, Dhaka, Chittagong]  [Bangladesh, Comilla, Barishal]
# 1    [Russia, Moscow, Novosibirsk]     [Russia, Petersburg, Samara]
# 2         [UK, London, Birmingham]        [UK, Mancheste, Plymouth]

# %%
df8.shape
# Out:
# (3, 2)
