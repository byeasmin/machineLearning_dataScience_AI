# %% [markdown]
# <a href="https://www.kaggle.com/code/yeasminbenin/day-15-feature-transformation?scriptVersionId=348556874" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ![image.png](attachment:e036f8cd-ce2c-4569-9347-a8361c4ba7f0.png)

# %% [markdown]
# ![image.png](attachment:0f4b649e-c11b-48a2-a946-56843af2e3b5.png)

# %% [markdown]
# ![image.png](attachment:60ed6118-a192-4193-99f3-9449a67a79cf.png)

# %% [markdown]
# ![image.png](attachment:8a2a33c0-deb0-4573-b89f-3e313c7c8535.png)

# %% [markdown]
# ![image.png](attachment:37b6fd94-60e6-4581-86d2-06587265ab5f.png)

# %% [markdown]
# ![image.png](attachment:5303e5fc-1f5c-4d2e-9bd2-d51c1f4225be.png)

# %% [markdown]
#  ![image.png](attachment:c7c6fb05-3ea0-4f4e-9995-b850718dc926.png)

# %% [markdown]
# # Advantages of feature transformation

# %% [markdown]
# ![image.png](attachment:d585f6cf-300d-4bc8-9e6b-0db28b6f1e09.png)
