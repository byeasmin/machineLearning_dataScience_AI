# %%
2+2
# Out:
# 4

# %%
3+8
# Out:
# 11

# %%
5+9
# Out:
# 14

# %%
'hi there!'
# Out:
# 'hi there!'

# %%
print("hello benin")
# Out:
# hello benin

# %%
name1 = "benin"
age1 = 23
print(f"My name is {name1} and I am {age1} years old.")
# Out:
# My name is benin and I am 23 years old.
