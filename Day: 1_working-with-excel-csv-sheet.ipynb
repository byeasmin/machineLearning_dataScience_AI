# %%
import os
import pandas as pd

# %%
os.listdir("/kaggle/input")
# Out:
# ['datasets']

# %%
os.listdir("/kaggle/input/datasets")
# Out:
# ['yeasminbenin']

# %%
os.listdir("/kaggle/input/datasets/yeasminbenin")
# Out:
# ['test-dataset-500-with-nulls']

# %%
os.listdir("/kaggle/input/datasets/yeasminbenin/test-dataset-500-with-nulls")
# Out:
# ['test_dataset_500_with_nulls.csv']

# %%
import os
import pandas as pd
os.listdir("/kaggle/input/datasets/yeasminbenin/test-dataset-500-with-nulls")
# Out:
# ['test_dataset_500_with_nulls.csv']

# %%
os.listdir("/kaggle/input/datasets/yeasminbenin/test-dataset-500-with-nulls")
# Out:
# ['test_dataset_500_with_nulls.csv']

# %%
df = pd.read_csv(
    "/kaggle/input/datasets/yeasminbenin/test-dataset-500-with-nulls/test_dataset_500_with_nulls.csv"
)

# %%
df
# Out:
#       id      name   age  gender    income  score category        city  \
# 0      1  User_001  21.0    Male  124121.0  51.92        C    Rajshahi
# 1      2  User_002  51.0  Female       NaN  55.96        A    Rajshahi
# 2      3  User_003  46.0     NaN   90373.0  50.76        D      Khulna
# 3      4  User_004  36.0   Other  134665.0  66.19        A      Khulna
# 4      5  User_005  36.0    Male   32316.0  79.41        A    Rajshahi
# ..   ...       ...   ...     ...       ...    ...      ...         ...
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 0    2025-01-01    Active
# 1    2025-01-02  Inactive
# 2    2025-01-03    Active
# ...

# %%
df = pd.read_csv("/kaggle/input/datasets/yeasminbenin/test-dataset-500-with-nulls/test_dataset_500_with_nulls.csv")

# %%
df
# Out:
#       id      name   age  gender    income  score category        city  \
# 0      1  User_001  21.0    Male  124121.0  51.92        C    Rajshahi
# 1      2  User_002  51.0  Female       NaN  55.96        A    Rajshahi
# 2      3  User_003  46.0     NaN   90373.0  50.76        D      Khulna
# 3      4  User_004  36.0   Other  134665.0  66.19        A      Khulna
# 4      5  User_005  36.0    Male   32316.0  79.41        A    Rajshahi
# ..   ...       ...   ...     ...       ...    ...      ...         ...
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 0    2025-01-01    Active
# 1    2025-01-02  Inactive
# 2    2025-01-03    Active
# ...

# %%
df.head()
# Out:
#    id      name   age  gender    income  score category      city        date  \
# 0   1  User_001  21.0    Male  124121.0  51.92        C  Rajshahi  2025-01-01
# 1   2  User_002  51.0  Female       NaN  55.96        A  Rajshahi  2025-01-02
# 2   3  User_003  46.0     NaN   90373.0  50.76        D    Khulna  2025-01-03
# 3   4  User_004  36.0   Other  134665.0  66.19        A    Khulna  2025-01-04
# 4   5  User_005  36.0    Male   32316.0  79.41        A  Rajshahi  2025-01-05
#
#      status
# 0    Active
# 1  Inactive
# 2    Active
# 3       NaN
# 4    Active

# %%
df.shape
# Out:
# (500, 10)

# %%
df.head(10)
# Out:
#    id      name   age  gender    income  score category      city        date  \
# 0   1  User_001  21.0    Male  124121.0  51.92        C  Rajshahi  2025-01-01
# 1   2  User_002  51.0  Female       NaN  55.96        A  Rajshahi  2025-01-02
# 2   3  User_003  46.0     NaN   90373.0  50.76        D    Khulna  2025-01-03
# 3   4  User_004  36.0   Other  134665.0  66.19        A    Khulna  2025-01-04
# 4   5  User_005  36.0    Male   32316.0  79.41        A  Rajshahi  2025-01-05
# 5   6  User_006  54.0  Female  139343.0  49.84        A     Dhaka  2025-01-06
# 6   7  User_007  21.0  Female  129781.0  56.50        B    Sylhet  2025-01-07
# 7   8  User_008  47.0    Male       NaN  95.48        C    Sylhet  2025-01-08
# 8   9  User_009  26.0    Male  114008.0  38.16        B  Rajshahi  2025-01-09
# 9  10  User_010  22.0    Male       NaN  64.95        A    Khulna  2025-01-10
#
#      status
# 0    Active
# 1  Inactive
# 2    Active
# 3       NaN
# 4    Active
# 5   Pending
# 6   Pending
# ...

# %%
df
# Out:
#       id      name   age  gender    income  score category        city  \
# 0      1  User_001  21.0    Male  124121.0  51.92        C    Rajshahi
# 1      2  User_002  51.0  Female       NaN  55.96        A    Rajshahi
# 2      3  User_003  46.0     NaN   90373.0  50.76        D      Khulna
# 3      4  User_004  36.0   Other  134665.0  66.19        A      Khulna
# 4      5  User_005  36.0    Male   32316.0  79.41        A    Rajshahi
# ..   ...       ...   ...     ...       ...    ...      ...         ...
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 0    2025-01-01    Active
# 1    2025-01-02  Inactive
# 2    2025-01-03    Active
# ...

# %% [markdown]
# **if want to import dataset from jupyter notebook then, first of all, store the dataset in the same folder, and then import the dataset, for example:**
#
# ![image.png](attachment:aa873568-6729-4bd2-9f6a-8a168509c856.png)
#
# ![image.png](attachment:919a3b58-6eca-4fab-b3f3-a7ddf3e0d772.png)

# %% [markdown]
# # First 5 rows (upper)

# %%
  df.head()
# Out:
#    id      name   age  gender    income  score category      city        date  \
# 0   1  User_001  21.0    Male  124121.0  51.92        C  Rajshahi  2025-01-01
# 1   2  User_002  51.0  Female       NaN  55.96        A  Rajshahi  2025-01-02
# 2   3  User_003  46.0     NaN   90373.0  50.76        D    Khulna  2025-01-03
# 3   4  User_004  36.0   Other  134665.0  66.19        A    Khulna  2025-01-04
# 4   5  User_005  36.0    Male   32316.0  79.41        A  Rajshahi  2025-01-05
#
#      status
# 0    Active
# 1  Inactive
# 2    Active
# 3       NaN
# 4    Active

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Last 5 rows (bottom)

# %%
df.tail()
# Out:
#       id      name   age  gender    income  score category        city  \
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 495  2026-05-11  Inactive
# 496  2026-05-12    Active
# 497  2026-05-13   Pending
# 498  2026-05-14   Pending
# 499  2026-05-15  Inactive

# %%
df.head(10)
# Out:
#    id      name   age  gender    income  score category      city        date  \
# 0   1  User_001  21.0    Male  124121.0  51.92        C  Rajshahi  2025-01-01
# 1   2  User_002  51.0  Female       NaN  55.96        A  Rajshahi  2025-01-02
# 2   3  User_003  46.0     NaN   90373.0  50.76        D    Khulna  2025-01-03
# 3   4  User_004  36.0   Other  134665.0  66.19        A    Khulna  2025-01-04
# 4   5  User_005  36.0    Male   32316.0  79.41        A  Rajshahi  2025-01-05
# 5   6  User_006  54.0  Female  139343.0  49.84        A     Dhaka  2025-01-06
# 6   7  User_007  21.0  Female  129781.0  56.50        B    Sylhet  2025-01-07
# 7   8  User_008  47.0    Male       NaN  95.48        C    Sylhet  2025-01-08
# 8   9  User_009  26.0    Male  114008.0  38.16        B  Rajshahi  2025-01-09
# 9  10  User_010  22.0    Male       NaN  64.95        A    Khulna  2025-01-10
#
#      status
# 0    Active
# 1  Inactive
# 2    Active
# 3       NaN
# 4    Active
# 5   Pending
# 6   Pending
# ...

# %%
df.tail(10)
# Out:
#       id      name   age  gender    income  score category        city  \
# 490  491  User_491  58.0  Female   52103.0  90.92        B  Chattogram
# 491  492  User_492  55.0  Female   81083.0  55.83      NaN         NaN
# 492  493  User_493  50.0    Male       NaN  58.45        A       Dhaka
# 493  494  User_494  43.0  Female   59968.0  38.59        D    Rajshahi
# 494  495  User_495  30.0  Female   70368.0  58.23        D      Khulna
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 490  2026-05-06   Pending
# 491  2026-05-07   Pending
# 492  2026-05-08    Active
# 493  2026-05-09    Active
# 494  2026-05-10  Inactive
# ...

# %% [markdown]
# # Print the values of df

# %%
df.values
# Out:
# array([[1, 'User_001', 21.0, ..., 'Rajshahi', '2025-01-01', 'Active'],
#        [2, 'User_002', 51.0, ..., 'Rajshahi', '2025-01-02', 'Inactive'],
#        [3, 'User_003', 46.0, ..., 'Khulna', '2025-01-03', 'Active'],
#        ...,
#        [498, 'User_498', 34.0, ..., 'Sylhet', '2026-05-13', 'Pending'],
#        [499, 'User_499', 57.0, ..., 'Chattogram', '2026-05-14',
#         'Pending'],
#        [500, 'User_500', 36.0, ..., 'Sylhet', '2026-05-15', 'Inactive']],
#       dtype=object)

# %% [markdown]
# # Print the column index of df

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'gender', 'income', 'score', 'category', 'city',
#        'date', 'status'],
#       dtype='object')

# %% [markdown]
# # Print the row index of df

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df.head(3)
# Out:
#    id      name   age  gender    income  score category      city        date  \
# 0   1  User_001  21.0    Male  124121.0  51.92        C  Rajshahi  2025-01-01
# 1   2  User_002  51.0  Female       NaN  55.96        A  Rajshahi  2025-01-02
# 2   3  User_003  46.0     NaN   90373.0  50.76        D    Khulna  2025-01-03
#
#      status
# 0    Active
# 1  Inactive
# 2    Active

# %% [markdown]
# # Specific column

# %%
df.name
# Out:
# 0      User_001
# 1      User_002
# 2      User_003
# 3      User_004
# 4      User_005
#          ...
# 495    User_496
# 496    User_497
# 497    User_498
# 498    User_499
# 499    User_500
# Name: name, Length: 500, dtype: object

# %%
df.category
# Out:
# 0      C
# 1      A
# 2      D
# 3      A
# 4      A
#       ..
# 495    C
# 496    B
# 497    B
# 498    B
# 499    C
# Name: category, Length: 500, dtype: object

# %%
df.name.head()
# Out:
# 0    User_001
# 1    User_002
# 2    User_003
# 3    User_004
# 4    User_005
# Name: name, dtype: object

# %%
df.name.shape
# Out:
# (500,)

# %%
df['name'].head()
# Out:
# 0    User_001
# 1    User_002
# 2    User_003
# 3    User_004
# 4    User_005
# Name: name, dtype: object

# %% [markdown]
# **If we have column with two words, for example, 'social networking' then we use this**

# %% [markdown]
# ### 1D

# %%
df['social networking']

# %% [markdown]
# ### 2D

# %%
df[['social networking']]

# %%
df['name']
# Out:
# 0      User_001
# 1      User_002
# 2      User_003
# 3      User_004
# 4      User_005
#          ...
# 495    User_496
# 496    User_497
# 497    User_498
# 498    User_499
# 499    User_500
# Name: name, Length: 500, dtype: object

# %%
df[['name']]
# Out:
#          name
# 0    User_001
# 1    User_002
# 2    User_003
# 3    User_004
# 4    User_005
# ..        ...
# 495  User_496
# 496  User_497
# 497  User_498
# 498  User_499
# 499  User_500
#
# [500 rows x 1 columns]

# %%
 df.name.head
# Out:
# <bound method NDFrame.head of 0      User_001
# 1      User_002
# 2      User_003
# 3      User_004
# 4      User_005
#          ...
# 495    User_496
# 496    User_497
# 497    User_498
# 498    User_499
# 499    User_500
# Name: name, Length: 500, dtype: object>

# %%
df['name'].head(6)
# Out:
# 0    User_001
# 1    User_002
# 2    User_003
# 3    User_004
# 4    User_005
# 5    User_006
# Name: name, dtype: object

# %%
df[['name']].head(6)
# Out:
#        name
# 0  User_001
# 1  User_002
# 2  User_003
# 3  User_004
# 4  User_005
# 5  User_006

# %% [markdown]
# # 2, 3 or more columns

# %%
df['name', 'age'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3811         try:
# -> 3812             return self._engine.get_loc(casted_key)
#    3813         except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'age')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_58/3868767920.py in <cell line: 0>()
# ----> 1 df['name', 'age'].head()
#
# ...

# %% [markdown]
# **The error is occurring bcz python is interpreting it as a list, so we need to use double square brackets ```[[]]```

# %%
df[['name', 'age']].head()
# Out:
#        name   age
# 0  User_001  21.0
# 1  User_002  51.0
# 2  User_003  46.0
# 3  User_004  36.0
# 4  User_005  36.0

# %%
df.head
# Out:
# <bound method NDFrame.head of       id      name   age  gender    income  score category        city  \
# 0      1  User_001  21.0    Male  124121.0  51.92        C    Rajshahi
# 1      2  User_002  51.0  Female       NaN  55.96        A    Rajshahi
# 2      3  User_003  46.0     NaN   90373.0  50.76        D      Khulna
# 3      4  User_004  36.0   Other  134665.0  66.19        A      Khulna
# 4      5  User_005  36.0    Male   32316.0  79.41        A    Rajshahi
# ..   ...       ...   ...     ...       ...    ...      ...         ...
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 0    2025-01-01    Active
# 1    2025-01-02  Inactive
# ...

# %%
df.head()
# Out:
#    id      name   age  gender    income  score category      city        date  \
# 0   1  User_001  21.0    Male  124121.0  51.92        C  Rajshahi  2025-01-01
# 1   2  User_002  51.0  Female       NaN  55.96        A  Rajshahi  2025-01-02
# 2   3  User_003  46.0     NaN   90373.0  50.76        D    Khulna  2025-01-03
# 3   4  User_004  36.0   Other  134665.0  66.19        A    Khulna  2025-01-04
# 4   5  User_005  36.0    Male   32316.0  79.41        A  Rajshahi  2025-01-05
#
#      status
# 0    Active
# 1  Inactive
# 2    Active
# 3       NaN
# 4    Active

# %% [markdown]
# # Sort values

# %%
df['name'].sort_values()
# Out:
# 0      User_001
# 1      User_002
# 2      User_003
# 3      User_004
# 4      User_005
#          ...
# 495    User_496
# 496    User_497
# 497    User_498
# 498    User_499
# 499    User_500
# Name: name, Length: 500, dtype: object

# %%
df['name'].sort_values(ascending=False)
# Out:
# 499    User_500
# 498    User_499
# 497    User_498
# 496    User_497
# 495    User_496
#          ...
# 4      User_005
# 3      User_004
# 2      User_003
# 1      User_002
# 0      User_001
# Name: name, Length: 500, dtype: object

# %%
df['name'].sort_values(ascending=True)
# Out:
# 0      User_001
# 1      User_002
# 2      User_003
# 3      User_004
# 4      User_005
#          ...
# 495    User_496
# 496    User_497
# 497    User_498
# 498    User_499
# 499    User_500
# Name: name, Length: 500, dtype: object

# %% [markdown]
# # Sort full dataset with respect to name

# %%
df.sort_values('name', ascending=False)
# Out:
#       id      name   age  gender    income  score category        city  \
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# ..   ...       ...   ...     ...       ...    ...      ...         ...
# 4      5  User_005  36.0    Male   32316.0  79.41        A    Rajshahi
# 3      4  User_004  36.0   Other  134665.0  66.19        A      Khulna
# 2      3  User_003  46.0     NaN   90373.0  50.76        D      Khulna
# 1      2  User_002  51.0  Female       NaN  55.96        A    Rajshahi
# 0      1  User_001  21.0    Male  124121.0  51.92        C    Rajshahi
#
#            date    status
# 499  2026-05-15  Inactive
# 498  2026-05-14   Pending
# 497  2026-05-13   Pending
# ...

# %%
df.sort_values('name', ascending=True)
# Out:
#       id      name   age  gender    income  score category        city  \
# 0      1  User_001  21.0    Male  124121.0  51.92        C    Rajshahi
# 1      2  User_002  51.0  Female       NaN  55.96        A    Rajshahi
# 2      3  User_003  46.0     NaN   90373.0  50.76        D      Khulna
# 3      4  User_004  36.0   Other  134665.0  66.19        A      Khulna
# 4      5  User_005  36.0    Male   32316.0  79.41        A    Rajshahi
# ..   ...       ...   ...     ...       ...    ...      ...         ...
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 0    2025-01-01    Active
# 1    2025-01-02  Inactive
# 2    2025-01-03    Active
# ...

# %% [markdown]
# # Statistical analysis

# %%
df.describe()
# Out:
#                id         age         income       score
# count  500.000000  475.000000     475.000000  475.000000
# mean   250.500000   38.854737   83703.265263   67.449747
# std    144.481833   12.372129   38924.997219   18.962977
# min      1.000000   18.000000   15166.000000   35.150000
# 25%    125.750000   28.000000   52707.500000   50.795000
# 50%    250.500000   39.000000   82892.000000   66.300000
# 75%    375.250000   50.000000  117978.000000   83.940000
# max    500.000000   60.000000  149831.000000   99.960000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       id      name   age  gender    income  score category        city  \
# 0      1  User_001  21.0    Male  124121.0  51.92        C    Rajshahi
# 1      2  User_002  51.0  Female       NaN  55.96        A    Rajshahi
# 2      3  User_003  46.0     NaN   90373.0  50.76        D      Khulna
# 3      4  User_004  36.0   Other  134665.0  66.19        A      Khulna
# 4      5  User_005  36.0    Male   32316.0  79.41        A    Rajshahi
# ..   ...       ...   ...     ...       ...    ...      ...         ...
# 495  496  User_496  35.0  Female   73229.0  52.21        C      Sylhet
# 496  497  User_497  23.0  Female   89406.0  74.68        B  Chattogram
# 497  498  User_498  34.0  Female  120379.0  48.35        B      Sylhet
# 498  499  User_499  57.0   Other   78076.0  92.74        B  Chattogram
# 499  500  User_500  36.0  Female       NaN  95.43        C      Sylhet
#
#            date    status
# 0    2025-01-01    Active
# 1    2025-01-02  Inactive
# ...

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_58/1134722465.py in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11074         cols = data.columns
#   11075         idx = cols.copy()
# > 11076         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11077
#   11078         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    2000         if dtype is not None:
#    2001             dtype = np.dtype(dtype)
# -> 2002         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003         if result.dtype is not dtype:
#    2004             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.corr(numeric_only=True)
# Out:
#               id       age    income     score
# id      1.000000 -0.022720 -0.058632 -0.002009
# age    -0.022720  1.000000 -0.089377 -0.049658
# income -0.058632 -0.089377  1.000000  0.053527
# score  -0.002009 -0.049658  0.053527  1.000000

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#               id       age    income     score
# id      1.000000 -0.022720 -0.058632 -0.002009
# age    -0.022720  1.000000 -0.089377 -0.049658
# income -0.058632 -0.089377  1.000000  0.053527
# score  -0.002009 -0.049658  0.053527  1.000000

# %%
df = df.drop(columns=['name'])

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_58/1134722465.py in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11074         cols = data.columns
#   11075         idx = cols.copy()
# > 11076         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11077
#   11078         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    2000         if dtype is not None:
#    2001             dtype = np.dtype(dtype)
# -> 2002         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003         if result.dtype is not dtype:
#    2004             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'income', 'score', 'category', 'city', 'date',
#        'status'],
#       dtype='object')

# %%
df = df.drop(columns=['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_58/129530687.py in <cell line: 0>()
# ----> 1 df = df.drop(columns=['name'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5601                 weight  1.0     0.8
#    5602         """
# -> 5603         return super().drop(
#    5604             labels=labels,
#    5605             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808         for axis, labels in axes.items():
#    4809             if labels is not None:
# -> 4810                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4811
#    4812         if inplace:
#
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_58/1134722465.py in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11074         cols = data.columns
#   11075         idx = cols.copy()
# > 11076         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11077
#   11078         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    2000         if dtype is not None:
#    2001             dtype = np.dtype(dtype)
# -> 2002         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003         if result.dtype is not dtype:
#    2004             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df['Gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_58/1134722465.py in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11074         cols = data.columns
#   11075         idx = cols.copy()
# > 11076         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11077
#   11078         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    2000         if dtype is not None:
#    2001             dtype = np.dtype(dtype)
# -> 2002         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003         if result.dtype is not dtype:
#    2004             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df['gender'] = df['gender'].map({
    'Male': 0,
    'Female': 1,
    'Other': 2
})

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_58/1134722465.py in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11074         cols = data.columns
#   11075         idx = cols.copy()
# > 11076         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11077
#   11078         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    2000         if dtype is not None:
#    2001             dtype = np.dtype(dtype)
# -> 2002         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003         if result.dtype is not dtype:
#    2004             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.dtypes
# Out:
# id            int64
# age         float64
# gender      float64
# income      float64
# score       float64
# category     object
# city         object
# date         object
# status       object
# Gender      float64
# dtype: object

# %%
import os
import pandas as pd

# %%
os.listdir("/kaggle/input")
# Out:
# ['datasets']

# %%
os.listdir("/kaggle/input/datasets")
# Out:
# ['yeasminbenin']

# %%
os.listdir("/kaggle/input/datasets/yeasminbenin")
# Out:
# ['test-dataset-500-with-nulls', 'time-data']

# %%
os.listdir("/kaggle/input/datasets/yeasminbenin/time-data")
# Out:
# ['Screen Time Data.csv']

# %%
df1 = pd.read_csv("/kaggle/input/datasets/yeasminbenin/time-data/Screen Time Data.csv")

# %%
df1
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
df[['gender', 'Gender']].head(10)
# Out:
#    gender  Gender
# 0     0.0     0.0
# 1     1.0     1.0
# 2     NaN     NaN
# 3     2.0     NaN
# 4     0.0     0.0
# 5     1.0     1.0
# 6     1.0     1.0
# 7     0.0     0.0
# 8     0.0     0.0
# 9     0.0     0.0

# %%
df['gender'].equals(df['Gender'])
# Out:
# False

# %%
df[df['gender'] != df['Gender']][['gender', 'Gender']]
# Out:
#      gender  Gender
# 2       NaN     NaN
# 3       2.0     NaN
# 10      NaN     NaN
# 11      2.0     NaN
# 12      2.0     NaN
# ..      ...     ...
# 468     2.0     NaN
# 471     NaN     NaN
# 481     2.0     NaN
# 489     2.0     NaN
# 498     2.0     NaN
#
# [185 rows x 2 columns]

# %%
corr = df.drop(columns=['id']).corr(numeric_only=True)
corr
# Out:
#              age    gender    income     score    Gender
# age     1.000000 -0.029308 -0.089377 -0.049658 -0.110135
# gender -0.029308  1.000000 -0.080258 -0.018018  1.000000
# income -0.089377 -0.080258  1.000000  0.053527 -0.114363
# score  -0.049658 -0.018018  0.053527  1.000000 -0.047641
# Gender -0.110135  1.000000 -0.114363 -0.047641  1.000000

# %% [markdown]
# # Because some column has objects, numeric values etc

# %%
df.corr(numeric_only=True)
# Out:
#               id       age    gender    income     score    Gender
# id      1.000000 -0.022720 -0.019445 -0.058632 -0.002009  0.095594
# age    -0.022720  1.000000 -0.029308 -0.089377 -0.049658 -0.110135
# gender -0.019445 -0.029308  1.000000 -0.080258 -0.018018  1.000000
# income -0.058632 -0.089377 -0.080258  1.000000  0.053527 -0.114363
# score  -0.002009 -0.049658 -0.018018  0.053527  1.000000 -0.047641
# Gender  0.095594 -0.110135  1.000000 -0.114363 -0.047641  1.000000

# %%
df
# Out:
#       id   age  gender    income  score category        city        date  \
# 0      1  21.0     0.0  124121.0  51.92        C    Rajshahi  2025-01-01
# 1      2  51.0     1.0       NaN  55.96        A    Rajshahi  2025-01-02
# 2      3  46.0     NaN   90373.0  50.76        D      Khulna  2025-01-03
# 3      4  36.0     2.0  134665.0  66.19        A      Khulna  2025-01-04
# 4      5  36.0     0.0   32316.0  79.41        A    Rajshahi  2025-01-05
# ..   ...   ...     ...       ...    ...      ...         ...         ...
# 495  496  35.0     1.0   73229.0  52.21        C      Sylhet  2026-05-11
# 496  497  23.0     1.0   89406.0  74.68        B  Chattogram  2026-05-12
# 497  498  34.0     1.0  120379.0  48.35        B      Sylhet  2026-05-13
# 498  499  57.0     2.0   78076.0  92.74        B  Chattogram  2026-05-14
# 499  500  36.0     1.0       NaN  95.43        C      Sylhet  2026-05-15
#
#        status  Gender
# 0      Active     0.0
# 1    Inactive     1.0
# ...

# %% [markdown]
# # correlation for only numeric values

# %%
df.corr(numeric_only=True)
# Out:
#               id       age    gender    income     score    Gender
# id      1.000000 -0.022720 -0.019445 -0.058632 -0.002009  0.095594
# age    -0.022720  1.000000 -0.029308 -0.089377 -0.049658 -0.110135
# gender -0.019445 -0.029308  1.000000 -0.080258 -0.018018  1.000000
# income -0.058632 -0.089377 -0.080258  1.000000  0.053527 -0.114363
# score  -0.002009 -0.049658 -0.018018  0.053527  1.000000 -0.047641
# Gender  0.095594 -0.110135  1.000000 -0.114363 -0.047641  1.000000

# %% [markdown]
# # Correlation with heatmap

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Math plot

# %%
import matplotlib.pyplot as plt

# %%
df.corr(numeric_only=True)
# Out:
#               id       age    gender    income     score    Gender
# id      1.000000 -0.022720 -0.019445 -0.058632 -0.002009  0.095594
# age    -0.022720  1.000000 -0.029308 -0.089377 -0.049658 -0.110135
# gender -0.019445 -0.029308  1.000000 -0.080258 -0.018018  1.000000
# income -0.058632 -0.089377 -0.080258  1.000000  0.053527 -0.114363
# score  -0.002009 -0.049658 -0.018018  0.053527  1.000000 -0.047641
# Gender  0.095594 -0.110135  1.000000 -0.114363 -0.047641  1.000000

# %% [markdown]
# ## Put fig size

# %%
plt.figure(figsize=(10, 6))

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap = 'coolwarm', fmt = '.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Title

# %%
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # plot show

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='Blues', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='Greens', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='Purples', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='RdYlBu', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='viridis', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='magma', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Subsetting rows

# %%
df['age']> 50
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498     True
# 499    False
# Name: age, Length: 500, dtype: bool

# %% [markdown]
# # For categorize

# %%
df[df['age']>50]
# Out:
#       id   age  gender    income  score category        city        date  \
# 1      2  51.0     1.0       NaN  55.96        A    Rajshahi  2025-01-02
# 5      6  54.0     1.0  139343.0  49.84        A       Dhaka  2025-01-06
# 11    12  59.0     2.0  122983.0  44.78        D      Sylhet  2025-01-12
# 15    16  51.0     0.0  128047.0    NaN        D      Sylhet  2025-01-16
# 18    19  54.0     1.0   20624.0  42.19        A      Sylhet  2025-01-19
# ..   ...   ...     ...       ...    ...      ...         ...         ...
# 481  482  53.0     2.0   15224.0  73.08        A       Dhaka  2026-04-27
# 483  484  52.0     1.0   30129.0  79.17        D       Dhaka  2026-04-29
# 490  491  58.0     1.0   52103.0  90.92        B  Chattogram  2026-05-06
# 491  492  55.0     1.0   81083.0  55.83      NaN         NaN  2026-05-07
# 498  499  57.0     2.0   78076.0  92.74        B  Chattogram  2026-05-14
#
#        status  Gender
# 1    Inactive     1.0
# 5     Pending     1.0
# ...

# %% [markdown]
# # Subsetting with string values

# %%
df[df['city'] == 'Chattogram']
# Out:
#       id   age  gender    income  score category        city        date  \
# 21    22  33.0     0.0   24728.0  72.00        A  Chattogram  2025-01-22
# 23    24   NaN     2.0  128669.0  90.21        B  Chattogram  2025-01-24
# 26    27  35.0     2.0   25482.0  75.24        B  Chattogram  2025-01-27
# 33    34  41.0     0.0   57375.0  74.22        A  Chattogram  2025-02-03
# 34    35  56.0     1.0   23983.0  99.00        D  Chattogram  2025-02-04
# ..   ...   ...     ...       ...    ...      ...         ...         ...
# 463  464  36.0     0.0   21879.0  60.05        A  Chattogram  2026-04-09
# 485  486  28.0     1.0  131474.0  41.45        C  Chattogram  2026-05-01
# 490  491  58.0     1.0   52103.0  90.92        B  Chattogram  2026-05-06
# 496  497  23.0     1.0   89406.0  74.68        B  Chattogram  2026-05-12
# 498  499  57.0     2.0   78076.0  92.74        B  Chattogram  2026-05-14
#
#        status  Gender
# 21     Active     0.0
# 23        NaN     NaN
# ...

# %% [markdown]
# # Chattogram or Dhaka any one is true then true

# %%
df[(df['city'] == 'Chattogram') | (df['city'] == 'Dhaka')]
# Out:
#       id   age  gender    income  score category        city        date  \
# 5      6  54.0     1.0  139343.0  49.84        A       Dhaka  2025-01-06
# 10    11  40.0     NaN   51283.0  81.25        A       Dhaka  2025-01-11
# 17    18  23.0     0.0   81709.0  37.03        C       Dhaka         NaN
# 20    21  39.0     1.0   22552.0  50.71        B       Dhaka  2025-01-21
# 21    22  33.0     0.0   24728.0  72.00        A  Chattogram  2025-01-22
# ..   ...   ...     ...       ...    ...      ...         ...         ...
# 485  486  28.0     1.0  131474.0  41.45        C  Chattogram  2026-05-01
# 490  491  58.0     1.0   52103.0  90.92        B  Chattogram  2026-05-06
# 492  493  50.0     0.0       NaN  58.45        A       Dhaka  2026-05-08
# 496  497  23.0     1.0   89406.0  74.68        B  Chattogram  2026-05-12
# 498  499  57.0     2.0   78076.0  92.74        B  Chattogram  2026-05-14
#
#        status  Gender
# 5     Pending     1.0
# 10    Pending     NaN
# ...

# %% [markdown]
# # Alternative

# %%
df['city'].isin(['Dhaka', 'Chattogram'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496     True
# 497    False
# 498     True
# 499    False
# Name: city, Length: 500, dtype: bool

# %%
df[df['city'].isin(['Dhaka', 'Chattogram'])]
# Out:
#       id   age  gender    income  score category        city        date  \
# 5      6  54.0     1.0  139343.0  49.84        A       Dhaka  2025-01-06
# 10    11  40.0     NaN   51283.0  81.25        A       Dhaka  2025-01-11
# 17    18  23.0     0.0   81709.0  37.03        C       Dhaka         NaN
# 20    21  39.0     1.0   22552.0  50.71        B       Dhaka  2025-01-21
# 21    22  33.0     0.0   24728.0  72.00        A  Chattogram  2025-01-22
# ..   ...   ...     ...       ...    ...      ...         ...         ...
# 485  486  28.0     1.0  131474.0  41.45        C  Chattogram  2026-05-01
# 490  491  58.0     1.0   52103.0  90.92        B  Chattogram  2026-05-06
# 492  493  50.0     0.0       NaN  58.45        A       Dhaka  2026-05-08
# 496  497  23.0     1.0   89406.0  74.68        B  Chattogram  2026-05-12
# 498  499  57.0     2.0   78076.0  92.74        B  Chattogram  2026-05-14
#
#        status  Gender
# 5     Pending     1.0
# 10    Pending     NaN
# ...
