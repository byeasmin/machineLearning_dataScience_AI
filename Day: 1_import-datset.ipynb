# %% [markdown]
# # How to Import and Load Datasets in Jupyter Notebook, Google Colab, and Kaggle..
#
# When working with Python, **importing a library** and **loading a dataset** are two different things.

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("test_dataset_500_with_nulls.csv")

# %% [markdown]
# #### This loads the dataset into a Pandas DataFrame.

# %% [markdown]
# # 1. Jupyter Notebook: Local Dataset:
#
# **In a local Jupyter Notebook, datasets are usually stored somewhere on your computer.**

# %% [markdown]
# ## Example 1: Dataset and Notebook in the Same Folder:
#
# ```text
# MyProject/
# │
# ├── notebook.ipynb
# └── data.csv

# %% [markdown]
# **For CSV**

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# %% [markdown]
# **For Excel**

# %%
df = pd.read_excel("data.xlsx")

# %% [markdown]
# ## Example 2: Dataset Inside a Folder
#
# ```text
# MyProject/
# │
# ├── notebook.ipynb
# └── dataset/
#     └── data.csv

# %%
import pandas as pd

df = pd.read_csv("dataset/data.csv")

# %%
df = pd.read_excel("dataset/data.xlsx")

# %% [markdown]
# ## Example 3: Using an Absolute Path

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\YourName\Desktop\data.csv")

# %%
df = pd.read_csv("C:/Users/YourName/Desktop/data.csv")

# %% [markdown]
# # 2. Google Colab: Upload Dataset Directly:
#
# **Google Colab runs in a cloud environment, so local computer files are not automatically available.**
#
# **upload a file directly from your computer:**

# %%
from google.colab import files

uploaded = files.upload()

# %%
import pandas as pd

df = pd.read_csv("data.csv")

# %%
df = pd.read_excel("data.xlsx")

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

df = pd.read_csv("data.csv")

df.head()

# %% [markdown]
# # 3. Google Colab: Using Google Drive
#
# **For large datasets or datasets that you use repeatedly, Google Drive is more convenient.**

# %%
from google.colab import drive

drive.mount("/content/drive")

# %% [markdown]
# /content/drive/MyDrive/
#
#
# ``` text
# MyDrive/
# └── datasets/
#     └── data.csv

# %%
import pandas as pd

df = pd.read_csv(
    "/content/drive/MyDrive/datasets/data.csv"
)

# %%
df = pd.read_excel(
    "/content/drive/MyDrive/datasets/data.xlsx"
)

# %% [markdown]
# # 4. Google Colab: Image Dataset from Google Drive
#
# ``` text
#
# MyDrive/
# └── dataset/
#     ├── Training/
#     │   ├── Class_A/
#     │   ├── Class_B/
#     │   └── Class_C/
#     │
#     └── Testing/
#         ├── Class_A/
#         ├── Class_B/
#         └── Class_C/

# %%
TRAIN_DIR = "/content/drive/MyDrive/dataset/Training"
TEST_DIR = "/content/drive/MyDrive/dataset/Testing"

# %%
from torchvision import datasets

train_dataset = datasets.ImageFolder(TRAIN_DIR)
test_dataset = datasets.ImageFolder(TEST_DIR)
