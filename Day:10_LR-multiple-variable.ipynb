# %% [markdown]
# <a href="https://www.kaggle.com/code/yeasminbenin/day-10-lr-multiple-variable?scriptVersionId=345016574" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ![image.png](attachment:e8cfbe4f-55fc-4407-94f5-b2fa63064b86.png)

# %% [markdown]
# ![image.png](attachment:60f287bd-5a60-4f18-8619-d27cfb7020f4.png)

# %% [markdown]
# ![image.png](attachment:67fe25ae-7824-4dc1-bda4-c299b3dbba81.png)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
 import os

# %%
os.listdir("/kaggle/input")
# Out:
# ['datasets']

# %%
os.listdir("/kaggle/input/datasets")
# Out:
# ['yeasminbenin']

# %%
os.listdir("/kaggle/input/datasets/yeasminbenin")
# Out:
# ['car-data']

# %%
os.listdir("/kaggle/input/datasets/yeasminbenin/car-data")
# Out:
# ['car_risk_data.csv']

# %%
df = pd.read_csv("/kaggle/input/datasets/yeasminbenin/car-data/car_risk_data.csv")

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         NaN    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
df.experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     NaN
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
 df.experience.mean()
# Out:
# np.float64(6.6)

# %%
df.experience.median()
# Out:
# 5.0

# %%
e_fit = df.experience.median()

# %%
e_fit
# Out:
# 5.0

# %% [markdown]
# # To fill null value

# %%
df.experience = df.experience.fillna(e_fit)

# %%
df.experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     5.0
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         5.0    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['speed', 'car_age', 'experience']], df.risk)
# Out:
# LinearRegression()

# %%
reg.predict([[160, 10, 5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.37146872])

# %%
reg.coef_
# Out:
# array([ 0.33059217,  1.61053246, -6.20772074])

# %%
reg.intercept_
# Out:
# np.float64(33.41000091043588)

# %%
0.33059217*160 + 1.61053246*10 + -6.20772074*5 + 33.41000091043588
# Out:
# 71.37146901043589
